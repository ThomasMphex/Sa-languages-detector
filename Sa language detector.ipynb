# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /opt/anaconda3/lib/python3.11/site-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.65.5)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in /opt/anaconda3/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /opt/anaconda3/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
data= pd.read_csv('SA_official_languages.csv')

# %%
data
# Out:
#       lang_id                                               text
# 0         xho  umgaqo-siseko wenza amalungiselelo kumaziko ax...
# 1         xho  i-dha iya kuba nobulumko bokubeka umsebenzi na...
# 2         eng  the province of kwazulu-natal department of tr...
# 3         nso  o netefatša gore o ba file dilo ka moka tše le...
# 4         ven  khomishini ya ndinganyiso ya mbeu yo ewa maana...
# ...       ...                                                ...
# 32995     tsn  popo ya dipolateforomo tse ke go tlisa boetele...
# 32996     sot  modise mosadi na o ntse o sa utlwe hore thaban...
# 32997     eng  closing date for the submission of completed t...
# 32998     xho  nawuphina umntu ofunyenwe enetyala phantsi kwa...
# 32999     sot  mafapha a mang le ona a lokela ho etsa ditlale...
#
# [33000 rows x 2 columns]

# %%
data['lang_id'].value_counts()
# Out:
# lang_id
# xho    3000
# eng    3000
# nso    3000
# ven    3000
# tsn    3000
# nbl    3000
# zul    3000
# ssw    3000
# tso    3000
# sot    3000
# afr    3000
# Name: count, dtype: int64

# %%
texts = data['text'].values
labels = data['lang_id'].values

# %%
texts
# Out:
# array(['umgaqo-siseko wenza amalungiselelo kumaziko axhasa ulawulo lwesininzi kunye nokuthath inxaxheba kwabafazi ezi ziquka phakathi kwezinye zazo ikomishoni yokulingana ngokwesini ikomishoni yamalungelo oluntu lomzantsi afrika',
#        'i-dha iya kuba nobulumko bokubeka umsebenzi naphi na kwisebe ngokusekwe kwiimfuno zokusebenza zalo emva kokubonana nomsebenzi kunye okanye imanyano yakhe ukuba ulandulo lomntu onjalo alufanelekanga i-dha mayibize uncedo olufanelekileyo elungelweni layo',
#        'the province of kwazulu-natal department of transport invites tenders from established contractors experienced in bridge construction for the construction of the kwajolwayo tugela river pedestrian bridge near tugela ferry the duration of the project will be months',
#        ...,
#        'closing date for the submission of completed tenders is august at h no late submissions will be considered submissions must be enclosed in a sealed envelope and addressed to the chief executive officer at the above address',
#        'nawuphina umntu ofunyenwe enetyala phantsi kwalo mthetho ujongene ujungene nesohlwayo sokudliwa imali okanye ukuvalelwa ixesha elingadluliyo kwiinyanga ezintandathu okanye kuzo zombini isohlwayo sokudliwa imali okanye ukuvalelwa',
#        'mafapha a mang le ona a lokela ho etsa ditlaleho tsa ona ho latela dipehelo tsa nema merero yohle e lokela ho hlahlojwa ke komiti ya ditaba tsa tikoloho eo e kenyeleditseng motsamaisi-kakaretso wa lefapha'],
#       dtype=object)

# %%
labels
# Out:
# array(['xho', 'xho', 'eng', ..., 'eng', 'xho', 'sot'], dtype=object)

# %%
# Tokenize text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
word_index = tokenizer.word_index

# %%
word_index
# Out:
# {'ya': 1,
#  'a': 2,
#  'le': 3,
#  'ka': 4,
#  'go': 5,
#  'e': 6,
#  'na': 7,
#  'u': 8,
#  'die': 9,
#  'wa': 10,
#  'the': 11,
#  'ba': 12,
#  'o': 13,
#  'ho': 14,
#  'ku': 15,
#  'of': 16,
#  'nga': 17,
#  'ke': 18,
#  'in': 19,
#  'di': 20,
#  'sa': 21,
#  'ha': 22,
#  'tsa': 23,
#  'se': 24,
#  'van': 25,
#  'vha': 26,
#  'mo': 27,
#  'to': 28,
#  'hi': 29,
#  'and': 30,
#  'la': 31,
#  'is': 32,
#  'en': 33,
#  'tse': 34,
#  'n': 35,
#  'i': 36,
#  'kha': 37,
#  'ga': 38,
#  'tša': 39,
#  'eka': 40,
#  'gore': 41,
#  'yo': 42,
#  'afrika': 43,
#  'tla': 44,
#  'kanye': 45,
#  'va': 46,
#  'te': 47,
#  'xa': 48,
#  'ta': 49,
#  're': 50,
#  'ukuba': 51,
#  'wat': 52,
#  'bona': 53,
#  'noma': 54,
#  'word': 55,
#  'as': 56,
#  'mme': 57,
#  'be': 58,
#  'kana': 59,
#  'om': 60,
#  'ye': 61,
#  'or': 62,
#  'hore': 63,
#  'dza': 64,
#  'by': 65,
#  'tshi': 66,
#  'nie': 67,
#  'fa': 68,
#  'for': 69,
#  'swi': 70,
#  'uma': 71,
#  'ri': 72,
#  'uri': 73,
#  'bo': 74,
#  'molao': 75,
#  'zwa': 76,
#  'kapa': 77,
#  'kumbe': 78,
#  'kutsi': 79,
#  'ge': 80,
#  'vir': 81,
#  'okanye': 82,
#  'goba': 83,
#  'yi': 84,
#  'that': 85,
#  'kwa': 86,
#  'loko': 87,
#  'het': 88,
#  'swa': 89,
#  'no': 90,
#  'b': 91,
#  'ukuthi': 92,
#  'tše': 93,
#  'zwi': 94,
#  'hu': 95,
#  'leswaku': 96,
#  'batho': 97,
#  'wo': 98,
#  'nobe': 99,
#  'motho': 100,
#  'leyi': 101,
#  'pele': 102,
#  'yona': 103,
#  'op': 104,
#  'yeo': 105,
#  'leswi': 106,
#  'r': 107,
#  'on': 108,
#  'kufanele': 109,
#  'namkha': 110,
#  'met': 111,
#  'aan': 112,
#  'ra': 113,
#  'wana': 114,
#  'ni': 115,
#  'tea': 116,
#  'moet': 117,
#  'with': 118,
#  'borwa': 119,
#  'nngwe': 120,
#  'sal': 121,
#  'kumele': 122,
#  'kan': 123,
#  'dit': 124,
#  'tsha': 125,
#  'khona': 126,
#  'ne': 127,
#  'ndi': 128,
#  'we': 129,
#  'nna': 130,
#  'tshwanetse': 131,
#  'dira': 132,
#  'bya': 133,
#  'kunye': 134,
#  'nako': 135,
#  'ngaphandle': 136,
#  'act': 137,
#  'wu': 138,
#  'this': 139,
#  'wena': 140,
#  'fanele': 141,
#  'kgotsa': 142,
#  'futhi': 143,
#  'dat': 144,
#  'lowu': 145,
#  'kufuneka': 146,
#  'karolo': 147,
#  'lapho': 148,
#  'vho': 149,
#  'deur': 150,
#  'an': 151,
#  'umsebenzi': 152,
#  'arali': 153,
#  'dzi': 154,
#  'moo': 155,
#  'any': 156,
#  'teng': 157,
#  'bja': 158,
#  'begodu': 159,
#  'jwa': 160,
#  'fela': 161,
#  'khou': 162,
#  'abantu': 163,
#  'futsi': 164,
#  'swanetše': 165,
#  'ntle': 166,
#  'eo': 167,
#  'ukuze': 168,
#  'kona': 169,
#  'c': 170,
#  'ita': 171,
#  'ḓo': 172,
#  'musi': 173,
#  'umuntu': 174,
#  'xi': 175,
#  'si': 176,
#  'ons': 177,
#  'are': 178,
#  'lo': 179,
#  'tšeo': 180,
#  'umthetho': 181,
#  's': 182,
#  'jy': 183,
#  'imali': 184,
#  'was': 185,
#  'setšhaba': 186,
#  'yena': 187,
#  'at': 188,
#  'lava': 189,
#  'mulayo': 190,
#  'ngendlela': 191,
#  'mongwe': 192,
#  'may': 193,
#  'gago': 194,
#  'not': 195,
#  'ao': 196,
#  'nawu': 197,
#  'maemo': 198,
#  'vhathu': 199,
#  'ndzi': 200,
#  'rona': 201,
#  'ena': 202,
#  'seo': 203,
#  'hierdie': 204,
#  'mokgwa': 205,
#  'jwalo': 206,
#  'it': 207,
#  'kakhulu': 208,
#  'bjalo': 209,
#  'muthu': 210,
#  'mabapi': 211,
#  'leng': 212,
#  'bese': 213,
#  'nkarhi': 214,
#  'khumbelo': 215,
#  'tshipembe': 216,
#  'such': 217,
#  'bao': 218,
#  'morago': 219,
#  'nje': 220,
#  'section': 221,
#  'etsa': 222,
#  'tsela': 223,
#  'lexi': 224,
#  'kahle': 225,
#  'has': 226,
#  'munhu': 227,
#  'bakeng': 228,
#  'metsi': 229,
#  'endla': 230,
#  'tswa': 231,
#  'mali': 232,
#  'zwo': 233,
#  'hulle': 234,
#  'which': 235,
#  'ine': 236,
#  'nang': 237,
#  'jou': 238,
#  'from': 239,
#  'ḽa': 240,
#  'lokhu': 241,
#  'loyi': 242,
#  'gona': 243,
#  'indlela': 244,
#  'vanhu': 245,
#  'lona': 246,
#  'gape': 247,
#  'south': 248,
#  'leo': 249,
#  'ngayo': 250,
#  'vona': 251,
#  'fana': 252,
#  'will': 253,
#  'nahone': 254,
#  'laha': 255,
#  'ngabe': 256,
#  'jaaka': 257,
#  'efe': 258,
#  'taolo': 259,
#  'ndlela': 260,
#  'kwaye': 261,
#  'isicelo': 262,
#  'gomme': 263,
#  'must': 264,
#  'kopo': 265,
#  'leri': 266,
#  'dingwe': 267,
#  'lokela': 268,
#  'tot': 269,
#  'mayelana': 270,
#  'kodwa': 271,
#  'gagwe': 272,
#  'lowo': 273,
#  'ona': 274,
#  'tlase': 275,
#  'thoma': 276,
#  'loku': 277,
#  'dintlha': 278,
#  'ook': 279,
#  'kube': 280,
#  'so': 281,
#  'd': 282,
#  'leti': 283,
#  'oor': 284,
#  'national': 285,
#  'ngaphambi': 286,
#  'lushaka': 287,
#  'shall': 288,
#  'setjhaba': 289,
#  'tshumelo': 290,
#  'muvhuso': 291,
#  'bohlokwa': 292,
#  'kgwebo': 293,
#  'mthetho': 294,
#  'ti': 295,
#  'xiyenge': 296,
#  'ile': 297,
#  'lefapha': 298,
#  'isikhathi': 299,
#  'feta': 300,
#  'ane': 301,
#  'bana': 302,
#  'bokgoni': 303,
#  'have': 304,
#  'tsamaiso': 305,
#  'moka': 306,
#  'mong': 307,
#  'ngwana': 308,
#  'minister': 309,
#  'lwa': 310,
#  'vhe': 311,
#  'bonyana': 312,
#  'emva': 313,
#  'tsona': 314,
#  'hao': 315,
#  'terms': 316,
#  'vhu': 317,
#  'ofe': 318,
#  'tshifhinga': 319,
#  'mfumo': 320,
#  'komiti': 321,
#  'lekgotla': 322,
#  'kuphela': 323,
#  'daar': 324,
#  'ofisi': 325,
#  'mabaka': 326,
#  'zwine': 327,
#  'if': 328,
#  'mmuso': 329,
#  'sy': 330,
#  'person': 331,
#  'mosebetsi': 332,
#  'godimo': 333,
#  'enige': 334,
#  'indien': 335,
#  'thuto': 336,
#  'kgolo': 337,
#  'thusa': 338,
#  'dzo': 339,
#  'phakathi': 340,
#  'naswona': 341,
#  'other': 342,
#  'gems': 343,
#  'njalo': 344,
#  'fanela': 345,
#  'aforika': 346,
#  'leyo': 347,
#  'umntu': 348,
#  'ntirho': 349,
#  'ama': 350,
#  'all': 351,
#  'lebaka': 352,
#  'latela': 353,
#  'imisebenzi': 354,
#  'mafhungo': 355,
#  'kute': 356,
#  'hone': 357,
#  'ngwaga': 358,
#  'puo': 359,
#  'suid': 360,
#  'xikombelo': 361,
#  'been': 362,
#  'court': 363,
#  'tiko': 364,
#  'tseo': 365,
#  'sicelo': 366,
#  'phambili': 367,
#  'ukusebenza': 368,
#  'nakong': 369,
#  'swo': 370,
#  'african': 371,
#  'hae': 372,
#  'tsena': 373,
#  'maleba': 374,
#  'lenaneo': 375,
#  'naha': 376,
#  'kuba': 377,
#  'government': 378,
#  'ukwenza': 379,
#  'ditirelo': 380,
#  'jalo': 381,
#  'ander': 382,
#  'yakho': 383,
#  'ntse': 384,
#  'tshedimosetso': 385,
#  'seng': 386,
#  'hune': 387,
#  'lapha': 388,
#  'ntlha': 389,
#  'lego': 390,
#  'africa': 391,
#  'feela': 392,
#  'khothe': 393,
#  'kufuze': 394,
#  'fhasi': 395,
#  'kuma': 396,
#  'wona': 397,
#  'yini': 398,
#  'nyika': 399,
#  'into': 400,
#  'neng': 401,
#  'bantfu': 402,
#  'ngo': 403,
#  'ngaphasi': 404,
#  'development': 405,
#  'tshebetso': 406,
#  'bva': 407,
#  'tou': 408,
#  'gongwe': 409,
#  'kokuba': 410,
#  'tiro': 411,
#  'shuma': 412,
#  'sakho': 413,
#  'gebruik': 414,
#  'jaar': 415,
#  'bosetšhaba': 416,
#  'izinto': 417,
#  'do': 418,
#  'mushumo': 419,
#  'tona': 420,
#  'apho': 421,
#  'nofana': 422,
#  'departement': 423,
#  'motheo': 424,
#  'public': 425,
#  'meer': 426,
#  'nkoka': 427,
#  'kobana': 428,
#  'zonke': 429,
#  'xo': 430,
#  'byi': 431,
#  'bile': 432,
#  'abasebenzi': 433,
#  'timhaka': 434,
#  'vhane': 435,
#  'muhasho': 436,
#  'umuntfu': 437,
#  'its': 438,
#  'department': 439,
#  'maloko': 440,
#  'songo': 441,
#  'ro': 442,
#  'he': 443,
#  'bophelo': 444,
#  'under': 445,
#  'wees': 446,
#  'khulu': 447,
#  'thendelo': 448,
#  'naga': 449,
#  'soos': 450,
#  'ngesikhathi': 451,
#  'who': 452,
#  'huvo': 453,
#  'uit': 454,
#  'mekgwa': 455,
#  'subsection': 456,
#  'mfanelo': 457,
#  'maak': 458,
#  'wakho': 459,
#  'per': 460,
#  'dzonga': 461,
#  'ngemuva': 462,
#  'baithuti': 463,
#  'tirha': 464,
#  'mina': 465,
#  'merero': 466,
#  'nanyana': 467,
#  'hina': 468,
#  'mintirho': 469,
#  'tlhokomelo': 470,
#  'service': 471,
#  'kgopelo': 472,
#  'muṅwe': 473,
#  'lama': 474,
#  'dzine': 475,
#  'xiyimo': 476,
#  'faneleke': 477,
#  'tirhisa': 478,
#  'hiv': 479,
#  'sena': 480,
#  'doen': 481,
#  'ngaphansi': 482,
#  'jo': 483,
#  'ithuta': 484,
#  'khethekanyo': 485,
#  'nakube': 486,
#  'indawo': 487,
#  'karhi': 488,
#  'murahu': 489,
#  'isibawo': 490,
#  'nasionale': 491,
#  'ditaba': 492,
#  'ulwazi': 493,
#  'yakhe': 494,
#  'teaho': 495,
#  'phanḓa': 496,
#  'thuso': 497,
#  'kgona': 498,
#  'kanti': 499,
#  'thata': 500,
#  'itela': 501,
#  'molaotheo': 502,
#  'abe': 503,
#  'ngalo': 504,
#  'raad': 505,
#  'nge': 506,
#  'sungula': 507,
#  'nangabe': 508,
#  'financial': 509,
#  'rixaka': 510,
#  'tshedimošo': 511,
#  'vhona': 512,
#  'ten': 513,
#  'mohlala': 514,
#  'amandla': 515,
#  'kuhle': 516,
#  'lefelo': 517,
#  'haholo': 518,
#  'rena': 519,
#  'mmušo': 520,
#  'time': 521,
#  'tirelo': 522,
#  'hambana': 523,
#  'empa': 524,
#  'amanzi': 525,
#  'mang': 526,
#  'taba': 527,
#  'state': 528,
#  'lokho': 529,
#  'landza': 530,
#  'sikhatsi': 531,
#  'mense': 532,
#  'itwa': 533,
#  'mona': 534,
#  'gare': 535,
#  'ko': 536,
#  'ek': 537,
#  'their': 538,
#  'kudu': 539,
#  'sebaka': 540,
#  'mhaka': 541,
#  'tšwa': 542,
#  'oku': 543,
#  'kuya': 544,
#  'kgone': 545,
#  'njengoba': 546,
#  'hona': 547,
#  'sona': 548,
#  'ngenxa': 549,
#  'year': 550,
#  'mmoho': 551,
#  'kantsi': 552,
#  'endzhaku': 553,
#  'lebyi': 554,
#  'aansoek': 555,
#  'services': 556,
#  'ze': 557,
#  'dijo': 558,
#  'ehansi': 559,
#  'ḽi': 560,
#  'botlhokwa': 561,
#  'batla': 562,
#  'jwale': 563,
#  'hape': 564,
#  'madi': 565,
#  'water': 566,
#  'eli': 567,
#  'alle': 568,
#  'siku': 569,
#  'jikelele': 570,
#  'werk': 571,
#  'shumisa': 572,
#  'maikarabelo': 573,
#  'dirwa': 574,
#  'mmogo': 575,
#  'mbadelo': 576,
#  'palamente': 577,
#  'yabo': 578,
#  'ḓi': 579,
#  'ditjhelete': 580,
#  'ibe': 581,
#  'lefatshe': 582,
#  'tshitshavha': 583,
#  'tshwanetseng': 584,
#  'ditiro': 585,
#  'yavho': 586,
#  'ntshetsopele': 587,
#  'netefatsa': 588,
#  'dipuo': 589,
#  'nago': 590,
#  'phantsi': 591,
#  'gammogo': 592,
#  'ngemva': 593,
#  'ii': 594,
#  'our': 595,
#  'fhedzi': 596,
#  'mahungu': 597,
#  'palo': 598,
#  'tokelo': 599,
#  'provinsiale': 600,
#  'amba': 601,
#  'mošomo': 602,
#  'emahlweni': 603,
#  'sars': 604,
#  'puso': 605,
#  'maar': 606,
#  'kambe': 607,
#  'tala': 608,
#  'een': 609,
#  'billion': 610,
#  'wonke': 611,
#  'swona': 612,
#  'wet': 613,
#  'boleng': 614,
#  'letsatsi': 615,
#  'omunye': 616,
#  'kodvwa': 617,
#  'sengwe': 618,
#  'tloga': 619,
#  'shumiswa': 620,
#  'hy': 621,
#  'ngoba': 622,
#  'maatla': 623,
#  'ukuya': 624,
#  'were': 625,
#  'melao': 626,
#  'provincial': 627,
#  'elke': 628,
#  'within': 629,
#  'milawu': 630,
#  'more': 631,
#  'handle': 632,
#  'ndeme': 633,
#  'lakho': 634,
#  'šoma': 635,
#  'kwe': 636,
#  'ikonomi': 637,
#  'ngokuthi': 638,
#  'ditšhelete': 639,
#  'also': 640,
#  'muthelo': 641,
#  'ding': 642,
#  'kopano': 643,
#  'dirisa': 644,
#  'ḓa': 645,
#  'order': 646,
#  'bang': 647,
#  'tikologo': 648,
#  'iyi': 649,
#  'tumelelo': 650,
#  'kodwana': 651,
#  'aids': 652,
#  'fomo': 653,
#  'his': 654,
#  'hloka': 655,
#  'vatirhi': 656,
#  'bonke': 657,
#  'bobedi': 658,
#  'kuyo': 659,
#  'wanneer': 660,
#  'waar': 661,
#  'mishumo': 662,
#  'polelo': 663,
#  'foromo': 664,
#  'matimba': 665,
#  'tšona': 666,
#  'matla': 667,
#  'unwana': 668,
#  'nayo': 669,
#  'kusukela': 670,
#  'woke': 671,
#  'ditokelo': 672,
#  'basebetsi': 673,
#  'persoon': 674,
#  'wes': 675,
#  'nyaka': 676,
#  'tsohle': 677,
#  'bjo': 678,
#  'tanihi': 679,
#  'nne': 680,
#  'tindlela': 681,
#  'leloko': 682,
#  'phambi': 683,
#  'bangwe': 684,
#  'bolaodi': 685,
#  'endaweni': 686,
#  'fumana': 687,
#  'ukuqinisekisa': 688,
#  'tseba': 689,
#  'tsho': 690,
#  'melawana': 691,
#  'njani': 692,
#  'f': 693,
#  'kgoro': 694,
#  'm': 695,
#  'one': 696,
#  'swilaveko': 697,
#  'yonke': 698,
#  'amalungelo': 699,
#  'commission': 700,
#  'emsebenzini': 701,
#  'mathata': 702,
#  'lena': 703,
#  'authority': 704,
#  'maikutlo': 705,
#  'management': 706,
#  'tlhela': 707,
#  'kuwo': 708,
#  'dié': 709,
#  'lawa': 710,
#  'amogela': 711,
#  'gaan': 712,
#  'ube': 713,
#  'kule': 714,
#  'vhashumi': 715,
#  'tjhelete': 716,
#  'pholisi': 717,
#  'programme': 718,
#  'nḓila': 719,
#  'loyo': 720,
#  'than': 721,
#  'incwadi': 722,
#  'maitele': 723,
#  'letona': 724,
#  'komthetho': 725,
#  'pfanelo': 726,
#  'tsotlhe': 727,
#  'mbekanyamushumo': 728,
#  'botlalo': 729,
#  'these': 730,
#  'land': 731,
#  'mokgatlo': 732,
#  'sebedisa': 733,
#  'labo': 734,
#  'eningizimu': 735,
#  'farologaneng': 736,
#  'endliwa': 737,
#  'tšhelete': 738,
#  'isibonelo': 739,
#  'al': 740,
#  'ḓuvha': 741,
#  'report': 742,
#  'lengwe': 743,
#  'sigaba': 744,
#  'nnete': 745,
#  'inligting': 746,
#  'boitekanelo': 747,
#  'kwama': 748,
#  'g': 749,
#  'committee': 750,
#  'magareng': 751,
#  'karolwana': 752,
#  'naye': 753,
#  'wakhe': 754,
#  'kukhona': 755,
#  'nomoro': 756,
#  'vula': 757,
#  'swana': 758,
#  'kulo': 759,
#  'tshwanelo': 760,
#  'general': 761,
#  'khansele': 762,
#  'somthetho': 763,
#  'kuye': 764,
#  'pedi': 765,
#  'ditshebeletso': 766,
#  'isa': 767,
#  'cent': 768,
#  'dife': 769,
#  'mešomo': 770,
#  'mananeo': 771,
#  'ditho': 772,
#  'hwetša': 773,
#  'setso': 774,
#  'company': 775,
#  'selegae': 776,
#  'fhethu': 777,
#  'masipala': 778,
#  'regering': 779,
#  'lokha': 780,
#  'kgwedi': 781,
#  'information': 782,
#  'tšea': 783,
#  'fhela': 784,
#  'godu': 785,
#  'bontsha': 786,
#  'kakaretso': 787,
#  'itseng': 788,
#  'cape': 789,
#  'ntsena': 790,
#  'lenyalo': 791,
#  'deel': 792,
#  'baka': 793,
#  'taelo': 794,
#  'kutani': 795,
#  'bone': 796,
#  'njengobe': 797,
#  'sego': 798,
#  'lefelong': 799,
#  'moralo': 800,
#  'uya': 801,
#  'yoo': 802,
#  'loo': 803,
#  'sebetsa': 804,
#  'setho': 805,
#  'kazwelonke': 806,
#  'tani': 807,
#  'umtsetfo': 808,
#  'ezi': 809,
#  'nayikuthi': 810,
#  'bohle': 811,
#  'fapaneng': 812,
#  'mesebetsi': 813,
#  'bolela': 814,
#  'selemo': 815,
#  'after': 816,
#  'baie': 817,
#  'swirho': 818,
#  'council': 819,
#  'shango': 820,
#  'h': 821,
#  'phela': 822,
#  'mangwe': 823,
#  'kotsi': 824,
#  'ngokomthetho': 825,
#  'milayo': 826,
#  'afurika': 827,
#  'maemong': 828,
#  'fihla': 829,
#  'zabo': 830,
#  'vumbiwa': 831,
#  'cbnrm': 832,
#  'there': 833,
#  'wil': 834,
#  'sakhe': 835,
#  'kwekutsi': 836,
#  'muofisiri': 837,
#  'lembe': 838,
#  'morero': 839,
#  'board': 840,
#  'law': 841,
#  'ema': 842,
#  'karolong': 843,
#  'imvume': 844,
#  'artikel': 845,
#  'malugana': 846,
#  'date': 847,
#  'tiyisisa': 848,
#  'period': 849,
#  'made': 850,
#  'kunjalo': 851,
#  'umkhandlu': 852,
#  'abo': 853,
#  'umntwana': 854,
#  'but': 855,
#  'boikarabelo': 856,
#  'maphelo': 857,
#  'vaaki': 858,
#  'malebana': 859,
#  'akukho': 860,
#  'ririmi': 861,
#  'oko': 862,
#  'my': 863,
#  'ngawo': 864,
#  'mutirhi': 865,
#  'leano': 866,
#  'openbare': 867,
#  'tshebediso': 868,
#  'woo': 869,
#  'kuthi': 870,
#  'molato': 871,
#  'kry': 872,
#  'sekolo': 873,
#  'million': 874,
#  'binne': 875,
#  'dzhia': 876,
#  'dovha': 877,
#  'byo': 878,
#  'nnḓa': 879,
#  'respect': 880,
#  'bego': 881,
#  'saathu': 882,
#  'tirhisiwa': 883,
#  'tshelede': 884,
#  'katsa': 885,
#  'should': 886,
#  'her': 887,
#  'wua': 888,
#  'setifikeiti': 889,
#  'ja': 890,
#  'kwabo': 891,
#  'ingevolge': 892,
#  'potchefstroom': 893,
#  'kufaka': 894,
#  'nka': 895,
#  'basadi': 896,
#  'miv': 897,
#  'kaap': 898,
#  'kone': 899,
#  'fe': 900,
#  'molawana': 901,
#  'mutakalo': 902,
#  'vhone': 903,
#  'dula': 904,
#  'swinene': 905,
#  'hlangana': 906,
#  'members': 907,
#  'nuwe': 908,
#  'tswang': 909,
#  'stel': 910,
#  'tharo': 911,
#  'health': 912,
#  'tonkhe': 913,
#  'dilo': 914,
#  'masheleni': 915,
#  'bogolo': 916,
#  'uhlelo': 917,
#  'mafelo': 918,
#  'sephetho': 919,
#  'lu': 920,
#  'kota': 921,
#  'vhukati': 922,
#  'vhana': 923,
#  'eng': 924,
#  'kwakunye': 925,
#  'they': 926,
#  'tee': 927,
#  'misava': 928,
#  'umnyango': 929,
#  'mi': 930,
#  'masiku': 931,
#  'moya': 932,
#  'bothata': 933,
#  'kukho': 934,
#  'fetileng': 935,
#  'yomthetho': 936,
#  'zwe': 937,
#  'teen': 938,
#  'suka': 939,
#  'hul': 940,
#  'betaal': 941,
#  'semolao': 942,
#  'ngonyaka': 943,
#  'babe': 944,
#  'child': 945,
#  'ngaka': 946,
#  'laola': 947,
#  'ndhawu': 948,
#  'people': 949,
#  'abantwana': 950,
#  'system': 951,
#  'mekgatlo': 952,
#  'henhla': 953,
#  'nokuthi': 954,
#  'tshebeletso': 955,
#  'yaye': 956,
#  'sehlopha': 957,
#  'ngopfu': 958,
#  'yinwana': 959,
#  'eba': 960,
#  'ndzawulo': 961,
#  'timali': 962,
#  'hara': 963,
#  'amathuba': 964,
#  'ilungelo': 965,
#  'saps': 966,
#  'enye': 967,
#  'daardie': 968,
#  'fao': 969,
#  'nabo': 970,
#  'mpfumelelo': 971,
#  'romela': 972,
#  'ngokuya': 973,
#  'make': 974,
#  'wethu': 975,
#  'isigaba': 976,
#  'ofisini': 977,
#  'hezwi': 978,
#  'latelang': 979,
#  'nokuba': 980,
#  'zwithu': 981,
#  'leso': 982,
#  'ndivho': 983,
#  'before': 984,
#  'monna': 985,
#  'out': 986,
#  'pakeng': 987,
#  'mulayotewa': 988,
#  'bakhe': 989,
#  'haeba': 990,
#  'haar': 991,
#  'sebakeng': 992,
#  'dithoto': 993,
#  'diriša': 994,
#  'ma': 995,
#  'provide': 996,
#  'motlakase': 997,
#  'isaziso': 998,
#  'president': 999,
#  'mag': 1000,
#  ...}

# %%
# Mapping from dataset language IDs to Google Translator language codes
language_code_map = {
    'xho': 'xh',
    'eng': 'en',
    'nso': 'nso',  # Northern Sotho is the same as 'nso' in Google Translator
    'ven': 've',   # Venda
    'sot': 'st',   # Southern Sotho
    'tsn': 'tn',   # Tswana
    'afr': 'af',   # Afrikaans
    'zul': 'zu',   # Zulu
    'ssw': 'ss',   # Swati
    'tso': 'ts',   # Tsonga
    # Add other mappings as needed
}

# Applying the mapping to the dataset
def map_language_id(lang_id):
    return language_code_map.get(lang_id, lang_id)  # Default to the original if not found

# Apply the mapping
data['lang_id'] = data['lang_id'].apply(map_language_id)

# Print the updated DataFrame
print(data)
# Out:
#       lang_id                                               text
# 0          xh  umgaqo-siseko wenza amalungiselelo kumaziko ax...
# 1          xh  i-dha iya kuba nobulumko bokubeka umsebenzi na...
# 2          en  the province of kwazulu-natal department of tr...
# 3         nso  o netefatša gore o ba file dilo ka moka tše le...
# 4          ve  khomishini ya ndinganyiso ya mbeu yo ewa maana...
# ...       ...                                                ...
# 32995      tn  popo ya dipolateforomo tse ke go tlisa boetele...
# 32996      st  modise mosadi na o ntse o sa utlwe hore thaban...
# 32997      en  closing date for the submission of completed t...
# 32998      xh  nawuphina umntu ofunyenwe enetyala phantsi kwa...
# 32999      st  mafapha a mang le ona a lokela ho etsa ditlale...
#
# [33000 rows x 2 columns]

# %%
# Pad sequences
maxlen = 100   
data = pad_sequences(sequences, maxlen=maxlen)

# Convert labels to numerical format
label_tokenizer = Tokenizer()
label_tokenizer.fit_on_texts(labels)
label_sequences = np.array(label_tokenizer.texts_to_sequences(labels)) - 1

# Split data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, label_sequences, test_size=0.2, random_state=42)

# %%
y_test[7]
# Out:
# array([0])

# %%
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, BatchNormalization, Dropout
from tensorflow.keras.models import Sequential

# Define model
model = Sequential()
model.add(Embedding(input_dim=len(word_index) + 1, output_dim=128, input_length=maxlen))
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(len(label_tokenizer.word_index), activation='softmax'))

# Compile model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=40, validation_split=0.2)
# Out:
# Epoch 1/50
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 89s 165ms/step - accuracy: 0.7215 - loss: 0.9239 - val_accuracy: 0.9805 - val_loss: 0.0632
# Epoch 2/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 93s 176ms/step - accuracy: 0.9816 - loss: 0.0740 - val_accuracy: 0.9900 - val_loss: 0.0293
# Epoch 3/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 92s 174ms/step - accuracy: 0.9952 - loss: 0.0195 - val_accuracy: 0.9941 - val_loss: 0.0199
# Epoch 4/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 93s 176ms/step - accuracy: 0.9985 - loss: 0.0072 - val_accuracy: 0.9943 - val_loss: 0.0212
# Epoch 5/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 93s 177ms/step - accuracy: 0.9994 - loss: 0.0046 - val_accuracy: 0.9873 - val_loss: 0.0400
# Epoch 6/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 179ms/step - accuracy: 0.9989 - loss: 0.0070 - val_accuracy: 0.9854 - val_loss: 0.0705
# Epoch 7/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 177ms/step - accuracy: 0.9956 - loss: 0.0178 - val_accuracy: 0.9873 - val_loss: 0.0543
# Epoch 8/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 98s 185ms/step - accuracy: 0.9785 - loss: 0.0728 - val_accuracy: 0.9799 - val_loss: 0.0884
# Epoch 9/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 178ms/step - accuracy: 0.9923 - loss: 0.0303 - val_accuracy: 0.9917 - val_loss: 0.0333
# Epoch 10/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 177ms/step - accuracy: 0.9976 - loss: 0.0099 - val_accuracy: 0.9932 - val_loss: 0.0206
# Epoch 11/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 93s 177ms/step - accuracy: 0.9974 - loss: 0.0132 - val_accuracy: 0.9956 - val_loss: 0.0219
# Epoch 12/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 95s 179ms/step - accuracy: 0.9997 - loss: 0.0019 - val_accuracy: 0.9955 - val_loss: 0.0189
# Epoch 13/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 95s 179ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 0.9847 - val_loss: 0.0790
# Epoch 14/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 178ms/step - accuracy: 0.9972 - loss: 0.0119 - val_accuracy: 0.9909 - val_loss: 0.0377
# Epoch 15/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 178ms/step - accuracy: 0.9970 - loss: 0.0147 - val_accuracy: 0.9926 - val_loss: 0.0278
# Epoch 16/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 179ms/step - accuracy: 0.9981 - loss: 0.0071 - val_accuracy: 0.9911 - val_loss: 0.0312
# Epoch 17/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 96s 182ms/step - accuracy: 0.9988 - loss: 0.0053 - val_accuracy: 0.9937 - val_loss: 0.0291
# Epoch 18/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 95s 179ms/step - accuracy: 0.9985 - loss: 0.0074 - val_accuracy: 0.9962 - val_loss: 0.0167
# Epoch 19/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 179ms/step - accuracy: 0.9992 - loss: 0.0037 - val_accuracy: 0.9945 - val_loss: 0.0276
# Epoch 20/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 98s 184ms/step - accuracy: 0.9992 - loss: 0.0048 - val_accuracy: 0.9941 - val_loss: 0.0258
# Epoch 21/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 96s 181ms/step - accuracy: 0.9989 - loss: 0.0049 - val_accuracy: 0.9937 - val_loss: 0.0320
# Epoch 22/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 96s 182ms/step - accuracy: 0.9991 - loss: 0.0053 - val_accuracy: 0.9900 - val_loss: 0.0371
# Epoch 23/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 96s 182ms/step - accuracy: 0.9993 - loss: 0.0034 - val_accuracy: 0.9953 - val_loss: 0.0249
# Epoch 24/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 95s 180ms/step - accuracy: 0.9989 - loss: 0.0038 - val_accuracy: 0.9930 - val_loss: 0.0302
# Epoch 25/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 92s 175ms/step - accuracy: 0.9990 - loss: 0.0047 - val_accuracy: 0.9877 - val_loss: 0.0655
# Epoch 26/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 93s 175ms/step - accuracy: 0.9994 - loss: 0.0043 - val_accuracy: 0.9937 - val_loss: 0.0322
# Epoch 27/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 93s 176ms/step - accuracy: 0.9991 - loss: 0.0037 - val_accuracy: 0.9928 - val_loss: 0.0377
# Epoch 28/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 178ms/step - accuracy: 0.9984 - loss: 0.0081 - val_accuracy: 0.9936 - val_loss: 0.0402
# Epoch 29/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 178ms/step - accuracy: 0.9990 - loss: 0.0061 - val_accuracy: 0.9934 - val_loss: 0.0325
# Epoch 30/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 97s 183ms/step - accuracy: 0.9988 - loss: 0.0048 - val_accuracy: 0.9949 - val_loss: 0.0268
# Epoch 31/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 100s 188ms/step - accuracy: 0.9995 - loss: 0.0046 - val_accuracy: 0.9934 - val_loss: 0.0283
# Epoch 32/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 104s 197ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9934 - val_loss: 0.0333
# Epoch 33/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 100s 189ms/step - accuracy: 0.9998 - loss: 0.0014 - val_accuracy: 0.9947 - val_loss: 0.0292
# Epoch 34/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 93s 176ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 0.9953 - val_loss: 0.0289
# Epoch 35/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 178ms/step - accuracy: 0.9992 - loss: 0.0057 - val_accuracy: 0.9941 - val_loss: 0.0357
# Epoch 36/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 178ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9928 - val_loss: 0.0465
# Epoch 37/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 178ms/step - accuracy: 0.9996 - loss: 0.0025 - val_accuracy: 0.9941 - val_loss: 0.0292
# Epoch 38/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 93s 177ms/step - accuracy: 0.9999 - loss: 9.4946e-04 - val_accuracy: 0.9934 - val_loss: 0.0320
# Epoch 39/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 179ms/step - accuracy: 1.0000 - loss: 6.1662e-04 - val_accuracy: 0.9955 - val_loss: 0.0248
# Epoch 40/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 178ms/step - accuracy: 0.9994 - loss: 0.0028 - val_accuracy: 0.9939 - val_loss: 0.0400
# Epoch 41/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 177ms/step - accuracy: 0.9993 - loss: 0.0029 - val_accuracy: 0.9956 - val_loss: 0.0312
# Epoch 42/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 178ms/step - accuracy: 0.9998 - loss: 0.0011 - val_accuracy: 0.9930 - val_loss: 0.0389
# Epoch 43/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 94s 179ms/step - accuracy: 0.9993 - loss: 0.0025 - val_accuracy: 0.9936 - val_loss: 0.0478
# Epoch 44/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 95s 180ms/step - accuracy: 0.9988 - loss: 0.0071 - val_accuracy: 0.9913 - val_loss: 0.0539
# Epoch 45/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 96s 183ms/step - accuracy: 0.9992 - loss: 0.0033 - val_accuracy: 0.9911 - val_loss: 0.0611
# Epoch 46/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 99s 187ms/step - accuracy: 0.9995 - loss: 0.0014 - val_accuracy: 0.9945 - val_loss: 0.0302
# Epoch 47/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 99s 188ms/step - accuracy: 0.9998 - loss: 0.0016 - val_accuracy: 0.9955 - val_loss: 0.0276
# Epoch 48/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 98s 186ms/step - accuracy: 0.9999 - loss: 6.4743e-04 - val_accuracy: 0.9934 - val_loss: 0.0392
# Epoch 49/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 100s 189ms/step - accuracy: 0.9996 - loss: 0.0042 - val_accuracy: 0.9943 - val_loss: 0.0333
# Epoch 50/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 97s 183ms/step - accuracy: 0.9999 - loss: 4.5781e-04 - val_accuracy: 0.9962 - val_loss: 0.0205

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Loss: {loss}')
print(f'Accuracy: {accuracy}')
# Out:
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.9901 - loss: 0.0877
# Loss: 0.06670039147138596
# Accuracy: 0.9913636445999146

# %%
# !pip install keras
# !pip install tensorflow
# Out:
# Requirement already satisfied: keras in /opt/anaconda3/lib/python3.11/site-packages (3.4.1)
# Requirement already satisfied: absl-py in /opt/anaconda3/lib/python3.11/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.11/site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in /opt/anaconda3/lib/python3.11/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /opt/anaconda3/lib/python3.11/site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /opt/anaconda3/lib/python3.11/site-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /opt/anaconda3/lib/python3.11/site-packages (from keras) (0.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.11/site-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from optree->keras) (4.9.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)
# Requirement already satisfied: tensorflow in /opt/anaconda3/lib/python3.11/site-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.65.5)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in /opt/anaconda3/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /opt/anaconda3/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.0)

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import tokenizer_from_json
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Assuming 'model', 'tokenizer', and 'label_tokenizer' have been defined and loaded properly
# Assuming maxlen is defined based on the training data

# Mapping from the predicted labels to Google Translator language codes
language_code_map = {
    'xho': 'xh',
    'eng': 'en',
    'nso': 'nso',
    'ven': 've',
    'sot': 'st',
    'tsn': 'tn',
    'afr': 'af',
    'zul': 'zu',
    'ssw': 'ss',
    'tso': 'ts',
    # Add any additional mappings as necessary
}

# Function to predict the language of a given text
def predict_language(text):
    sequence = tokenizer.texts_to_sequences([text])
    padded_sequence = pad_sequences(sequence, maxlen=maxlen)
    prediction = model.predict(padded_sequence)
    label = label_tokenizer.index_word[np.argmax(prediction) + 1]
    # Map to Google Translator language code
    google_lang_code = language_code_map.get(label, label)
    return google_lang_code

# Example prediction
print(predict_language("umgaqo-siseko wenza amalungiselelo kumaziko"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# xh

# %%
3.4042077e-07
# Out:
# 3.4042077e-07

# %%
# Save the model in HDF5 format
model.save('language_detection_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import pickle

# Save the text tokenizer
with open('text_tokenizer.pkl', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# Save the label tokenizer
with open('label_tokenizer.pkl', 'wb') as handle:
    pickle.dump(label_tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
